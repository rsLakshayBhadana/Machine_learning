# %% [markdown]
# # Numpy Implementation

# %%
import numpy as np
# Create a 2D Numpy array of size 1x3 with elements of your choice
arr1= np.array([[1,2,3]])
# print(arr1.shape)

# Create a Numpy array of length 50 with zeroes as its elements
arr2= np.zeros(50)

#Create a Numpy array of length 3x2 with elements of your choice
arr3= np.array([[1,2],[3,4],[4,5]])

arr4 = np.dot(arr1,arr3)

#Change 5th element of arr2 to a different number
arr2[4] = 4
# print( np.shape(arr4))
#Your code here

if np.shape(arr4)==(1,2) and arr2[4]!=0:
  print("Passed")
else:
  print("Fail")
# Out:
# Passed

# %%
import numpy as np

#Task: Perform the dot product of I and 9I+1 using numpy, here I is referred to as an 3x3 Identity matrix.

I = np.eye(3)
print(I.shape)

arr = np.dot(I,9*I + 1)
print(arr)
# Out:
# (3, 3)
# [[10.  1.  1.]
#  [ 1. 10.  1.]
#  [ 1.  1. 10.]]

# %% [markdown]
# # Pandas Implementation

# %%
import pandas as pd

## Create a DataFrame from a dictionary
data = {
    'Name': ['Ramesh', 'Mahesh', 'Suresh'],
    'Age': [25, 30, 35],
    'City': ['Bangalore', 'Mumbai', 'Delhi']
}
#Your code here

df = pd.DataFrame(data)

#Display the first 2 rows of the data frame
#Your code here
print(df.iloc[2,:])

#Print the age column
#Your code here
print(df["Age"])

#Filter rows where age is greater than 26
#Your code here
age_above_26 = df[df["Age"] > 26]
print(age_above_26)

#Add a new column 'Country' with the value 'India' for all rows
#Your code here
df["Country"] = 'India'
print(df)

data1 = {
    'Name': ['Ramesh', 'Mahesh', 'Suresh'],
    'Age': [25, None, 35],
    'City': ['Bangalore', 'Mumbai', 'Delhi']
}

df2= pd.DataFrame(data1)

# Fill missing values in the 'Age' column with the mean age

#Your code here

age_mean = df2["Age"].mean()
df2["Age"].fillna(age_mean,inplace = True)
print(df2)
# Out:
# Name    Suresh
# Age         35
# City     Delhi
# Name: 2, dtype: object
# 0    25
# 1    30
# 2    35
# Name: Age, dtype: int64
#      Name  Age    City
# 1  Mahesh   30  Mumbai
# 2  Suresh   35   Delhi
#      Name  Age       City Country
# 0  Ramesh   25  Bangalore   India
# 1  Mahesh   30     Mumbai   India
# 2  Suresh   35      Delhi   India
#      Name   Age       City
# 0  Ramesh  25.0  Bangalore
# 1  Mahesh  30.0     Mumbai
# 2  Suresh  35.0      Delhi

# %% [markdown]
# # Matplotlib Implementation

# %%
import matplotlib.pyplot as plt
import numpy as np



xpoints=np.array([1,2,3,4])
ypoints=np.array([2,4,6,8])

#Plot these points without drawing a line
#Your code here
plt.figure()
plt.plot(ypoints,xpoints,marker = "o",linestyle="None")
plt.xlabel("X_axis")
plt.ylabel("Y_axis")
plt.title("Randome sample plot1")
plt.show()

#Plotting with marker: Plot these points with a marker(Star marker)
#Your code here
plt.figure()
plt.plot(ypoints,xpoints,marker = "*",linestyle="None")
plt.xlabel("X_axis")
plt.ylabel("Y_axis")
plt.title("Randome sample plot2")
plt.show()


#Using fmt format, add circular marker,red color and Dashed line
#Your code here
plt.figure()
plt.plot(xpoints, ypoints,"x--r") # Now it should work correctly!
plt.xlabel("X_axis")
plt.ylabel("Y_axis")
plt.title("Randome sample plo3t")
plt.show()

#Add xlabel,ylabel and title for the plot.
#Your code here
# plt.xlabel("X_axis")
# plt.ylabel("Y_axis")
# plt.title("Randome sample plot")

#Create a scatter plot for xpoints and ypoints
#Your code here
plt.figure()
plt.scatter(xpoints,ypoints)
plt.xlabel("X_axis")
plt.ylabel("Y_axis")
plt.title("Randome sample plot4")
plt.show()

#Set color to the scatter plot. Blue,Green,Red and yellow color for each point respectively
colors = ["Blue","Green","Red","yellow"]
plt.scatter(xpoints,ypoints,c=colors)
plt.xlabel("X_axis")
plt.ylabel("Y_axis")
plt.title("Randome sample plot")
plt.show()

# %% [markdown]
# # Miscellaneous Modules Implementation

# %%
import random
import numpy as np

#Set the seed of random to 20
random.seed(20)

#Your code here

arr1=np.array([1,24,31,45,73,81,94,25])

#Using the random module pick 4 different random numbers from arr1 and return their sum.
random_elements = np.random.choice(arr1, size=4, replace=False)
print(random_elements.sum())
#Your code here
# Out:
# 272
